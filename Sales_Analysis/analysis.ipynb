# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("/home/will/data_visualization_project/sales_project_dataset.csv")

df =pd.DataFrame(data)

# Total Revenue
Total_Revenue = df["Revenue"].sum()

# Average Revenue per Trasition

Avrage_order_value = df["Revenue"].mean()

# Top Revenue-Generating Products

Revenue_by_product =(
    df.groupby("Product")["Revenue"]
    .sum()
    .sort_values(ascending=False)
)

# Revenue by Category

Revenue_by_category =(
    df.groupby("Category")["Revenue"]
    .sum()
    .sort_values(ascending=False)
)

# Revenue by Region

Revenue_by_region =(
    df.groupby("Region")["Revenue"]
    .sum()
    .sort_values(ascending=False)
)

# Regional Revenue Visualization

Revenue_by_region.plot(
     kind="bar",
     figsize=(10,5),
     title="Revenue by Region"
 )

plt.xlabel("Region")
plt.ylabel("Revenue")

plt.show()

# Revenue Calculation

df["Date"] = pd.to_datetime(df["Date"], errors="coerce")

df["Month"] = df["Date"].dt.to_period("M")

Montly_revenue = df.groupby("Month")["Revenue"].sum()

# Revenue Trend Analysis

Montly_revenue.plot(
     kind="line",
     figsize=(10,5),
     title="Montly Revenue"
 )

plt.xlabel("Month")
plt.ylabel("Revenue")


# Revenue by Year

# df["Date"] = pd.to_datetime(df["Date"], errors="coerce")

df["Year"] = df["Date"].dt.year
yearly_revenue = df.groupby("Year")["Revenue"].sum().reset_index()

plt.figure(figsize=(8,5))

sns.barplot(x="Year", y="Revenue", data=yearly_revenue)

plt.show()

print(yearly_revenue.head())
print(type(yearly_revenue))

# Revenue by product


data = pd.read_csv("/home/will/data_visualization_project/sales_project_dataset.csv")

df =pd.DataFrame(data)

# Total Revenue
Total_Revenue = df["Revenue"].sum()

# Average Revenue per Trasition

Avrage_order_value = df["Revenue"].mean()

# Top Revenue-Generating Products

Revenue_by_product =(
    df.groupby("Product")["Revenue"]
    .sum()
    .sort_values(ascending=False)
)

# Revenue by Category

Revenue_by_category =(
    df.groupby("Category")["Revenue"]
    .sum()
    .sort_values(ascending=False)
)

# Revenue by Region

Revenue_by_region =(
    df.groupby("Region")["Revenue"]
    .sum()
    .sort_values(ascending=False)
)

# Regional Revenue Visualization

Revenue_by_region.plot(
     kind="bar",
     figsize=(10,5),
     title="Revenue by Region"
 )

plt.xlabel("Region")
plt.ylabel("Revenue")

plt.show()

# Revenue Calculation

df["Date"] = pd.to_datetime(df["Date"], errors="coerce")

df["Month"] = df["Date"].dt.to_period("M")

Montly_revenue = df.groupby("Month")["Revenue"].sum()

# Revenue Trend Analysis

Montly_revenue.plot(
     kind="line",
     figsize=(10,5),
     title="Montly Revenue"
 )

plt.xlabel("Month")
plt.ylabel("Revenue")


# Revenue by Year

df["Date"] = pd.to_datetime(df["Date"], errors="coerce")

df["Year"] = df["Date"].dt.year
yearly_revenue = df.groupby("Year")["Revenue"].sum().reset_index()

plt.figure(figsize=(8,5))

sns.barplot(x="Year", y="Revenue", data=yearly_revenue)

plt.show()

print(yearly_revenue.head())
print(type(yearly_revenue))

# Revenue by product

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("/home/will/data_visualization_project/sales_project_dataset.csv")

df =pd.DataFrame(data)

# Total Revenue
Total_Revenue = df["Revenue"].sum()

# Average Revenue per Trasition

Avrage_order_value = df["Revenue"].mean()

# Top Revenue-Generating Products

Revenue_by_product =(
    df.groupby("Product")["Revenue"]
    .sum()
    .sort_values(ascending=False)
)

# Revenue by Category

Revenue_by_category =(
    df.groupby("Category")["Revenue"]
    .sum()
    .sort_values(ascending=False)
)

# Revenue by Region

Revenue_by_region =(
    df.groupby("Region")["Revenue"]
    .sum()
    .sort_values(ascending=False)
)

# Regional Revenue Visualization

Revenue_by_region.plot(
     kind="bar",
     figsize=(10,5),
     title="Revenue by Region"
)

plt.xlabel("Region")
plt.ylabel("Revenue")

plt.show()

# Revenue Calculation

df["Date"] = pd.to_datetime(df["Date"], errors="coerce")

df["Month"] = df["Date"].dt.to_period("M")

Montly_revenue = df.groupby("Month")["Revenue"].sum()

# Revenue Trend Analysis

Montly_revenue.plot(
     kind="line",
     figsize=(10,5),
     title="Montly Revenue"
)

plt.xlabel("Month")
plt.ylabel("Revenue")


# Revenue by Year

df["Date"] = pd.to_datetime(df["Date"], errors="coerce")

f["Year"] = df["Date"].dt.year
yearly_revenue = df.groupby("Year")["Revenue"].sum().reset_index()

plt.figure(figsize=(8,5))

sns.barplot(x="Year", y="Revenue", data=yearly_revenue)

plt.show()

print(yearly_revenue.head())
print(type(yearly_revenue))

# Top Product Chart


# pareto Analysis

pareto = Revenue_by_product.reset_index()

pareto["Cumulative_revenue"] = pareto["Revenue"].cumsum()
pareto["Cumulative_percentage"] =pareto["Cumulative_revenue"]/ pareto["Revenue"].sum() *100


# Pareto Chart 

pareto = pareto.sort_values(by="Revenue", ascending=False)

fig, ax1 = plt.subplots(figsize=(10,5))


ax1.bar(pareto["Product"], pareto["Revenue"])
ax1.set_ylabel("Revenue")
ax1.set_xlabel("Product")


ax2 = ax1.twinx()
ax2.plot(pareto["Product"], pareto["Cumulative_percentage"], marker="o")
ax2.set_ylabel("Cumulative %")


ax2.axhline(80, linestyle="--")

plt.title("Pareto Chart - Revenue by Product")

plt.show()
